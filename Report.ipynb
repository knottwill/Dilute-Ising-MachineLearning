# %% [markdown]
# # What I did ( to remember)
#
# Pure Ising Model:
# - Make a plot to show how many timepoints we need for the BINDER RATIOS to converge to equilibrium.
# - Make data: we guarantee independance of snapshots by using a different random configuration then converging to equilibrium for each snapshot
# - Plot magnetisation. Plot magnetic susceptibility.
# - Plot p1 and plot p2 and talk about how they are analogues
# - Make the cluster plot: p1 vs p2, then use KMeans to cluster. Get details of how many states of each temperature are in each cluster.
# - Comment on the ability of PCA + KMeans to separate ordered states from disordered ones
# - Find Tc + error bars (any method)
#
# Dilute Ising Model:
# - Make the same convergence plot for various values of x
# - Make data for different values of x
# - For each x, find Tc with error bars by the same method
# - Plot Tc vs x and compare to that of published results
#
# # Stuff to mention:
#
# We implemented periodic boundary conditions
#
# Definitely need to talk about method of data generation, why we did what we did.
#
# Important result: First PCA component is not an exact analogue of magnetisation for small lattices!
#
# Mention difficulty generating the data for the dilute ising model
#
# Due to the difference between the definition of the hamiltonian for the ising model vs the potts model. The 2D ising model has a different critical temperature to the 2D potts model with q=2 states
#
# The method of finding the point of change in a binary labeled continuous variable using an iterative search algorithm is a type of change point analysis. Specifically, it is an example of a change point detection algorithm that can be used to identify the point in a continuous variable where a change in the underlying distribution or process occurs. The iterative search algorithm used in this method is a specific implementation of a change point detection algorithm that aims to minimize the difference between the predicted and true point of change.

# %% [markdown]
# # Some stuff to say to explain what i did
#
# We show that PCA is capable of extracting macroscopic physics from the data, and then find the critical temperature using a clustering method
#
# This use of Principle Component Analysis to find critical behaviour has so far only been used on training data where below the critical temperature, the ordered states did in fact find the global minimum. If the low temperature ordered states were instead stuck in local minima (ie. consisting of many clusters of spins), then it is no longer possible to use this method to find the critical temperature.
# In this report I devise a method to find the critical temperature from these states using machine learning.

# %% [markdown]
# # Abstract
#
# ...
# In this report we expand upon this work by applying the same technique to uncover critical behaviour of the 4D and 5D Potts model
#
# In this report we investigate the extent to which unsupervised machine learning methods can dicipher the underlying physics of the dilute ising model
#
# We show that PCA is capable of extracting macroscopic physics from the data, and then find the critical temperature using a clustering method

# %% [markdown]
# # Introduction
#
# The use of principle component analysis to find the critical point of the 2D ising model has been extensively studied [put references here where it has been studied], but to date it has not been used to analyse the dilute ising model.
#
# We set J=1 and k=1 in this report

# %% [markdown]
# # Theory
#
# Talk about ising model theory and dilute ising model etc.

# %% [markdown]
# # Methods
#
# Talk about the stuff that I actually did (not theory)
#
# #### Generating training data
#
# Monte Carlo Metropolis
#
# Tested convergence of average before running to make it as computationally inexpensive as possible.
